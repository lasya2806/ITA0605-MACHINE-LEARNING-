# %% [markdown]
# exp 13

# %%
# EXPERIMENT 13
# Car Price Prediction using Linear Regression

import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

X = np.array([
    [1, 12000, 1200],
    [2, 18000, 1200],
    [3, 25000, 1300],
    [4, 35000, 1400],
    [5, 45000, 1500],
    [6, 55000, 1500],
    [7, 65000, 1600],
    [8, 75000, 1600],
    [9, 85000, 1800],
    [10, 95000, 1800]
])

y = np.array([
    8.5,
    8.0,
    7.4,
    6.8,
    6.1,
    5.5,
    5.0,
    4.5,
    4.0,
    3.5
])

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=42
)

model = LinearRegression()

model.fit(X_train, y_train)

y_pred = model.predict(X_test)

print("Actual Prices:", y_test)
print("Predicted Prices:", y_pred)

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error:", mse)
print("R2 Score:", r2)

new_car = np.array([[4, 38000, 1400]])

prediction = model.predict(new_car)

print("Predicted Car Price:", round(prediction[0], 2), "Lakhs")

plt.scatter(y_test, y_pred)

plt.xlabel("Actual Car Price (Lakhs)")
plt.ylabel("Predicted Car Price (Lakhs)")
plt.title("Car Price Prediction")

plt.show()
# Out:
# Actual Prices: [4.  8.  5.5]
# Predicted Prices: [3.90655738 7.95175644 5.65983607]
# Mean Squared Error: 0.012202177565463296
# R2 Score: 0.9955175674249318
# Predicted Car Price: 6.78 Lakhs
