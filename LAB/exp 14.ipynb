# %% [markdown]
# exp 14

# %%
# EXPERIMENT 14
# House Price Prediction

import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# Area, Distance from City, Number of Rooms
X = np.array([
    [900, 20, 1],
    [1100, 18, 1],
    [1300, 16, 2],
    [1500, 14, 2],
    [1700, 12, 2],
    [1900, 10, 3],
    [2100, 8, 3],
    [2300, 6, 4],
    [2500, 5, 4],
    [2700, 3, 5]
])

# Price in Lakhs
y = np.array([
    40,
    48,
    60,
    74,
    88,
    104,
    122,
    142,
    165,
    190
])

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

model = LinearRegression()

model.fit(X_train, y_train)

y_pred = model.predict(X_test)

print("Actual Prices:", y_test)

print("Predicted Prices:", y_pred)

print("Mean Squared Error:",
      mean_squared_error(y_test, y_pred))

print("R2 Score:",
      r2_score(y_test, y_pred))

new_house = np.array([[1800, 11, 3]])

prediction = model.predict(new_house)

print("Predicted House Price:",
      round(prediction[0], 2), "Lakhs")

plt.scatter(y_test, y_pred)

plt.xlabel("Actual House Price")
plt.ylabel("Predicted House Price")

plt.title("House Price Prediction")

plt.show()
# Out:
# Actual Prices: [165  48 104]
# Predicted Prices: [170.53846154  45.92307692 108.53846154]
# Mean Squared Error: 18.52859960547585
# R2 Score: 0.9918837050302111
# Predicted House Price: 102.62 Lakhs
